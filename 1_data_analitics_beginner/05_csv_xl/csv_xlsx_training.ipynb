# %% [markdown]
# # CSV

# %%
import pandas as pd

# %%
df = pd.read_csv("world-data-2023.csv")

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
df['Population'] = df['Population'].replace(',','',regex=True).fillna('0').astype(int)

# %%
new_df = df[df['Population'] > 50000000]

# %%
new_df
# Out:
#                               Country Density\n(P/Km2) Abbreviation  \
# 13                         Bangladesh            1,265           BD
# 23                             Brazil               25           BR
# 36                              China              153           CN
# 37                           Colombia               46           CO
# 45   Democratic Republic of the Congo               40           CD
# 51                              Egypt              103           EG
# 57                           Ethiopia              115           ET
# 60                             France              119           FR
# 64                            Germany              240           DE
# 77                              India              464           IN
# 78                          Indonesia              151           ID
# 79                               Iran               52           IR
# 83                              Italy              206           IT
# ...

# %%
new_df.to_csv('result.csv', index_label='index', sep=';')

# %% [markdown]
# # XLSX

# %%
df = pd.read_excel('world-data-2023.xlsx')

# %%
df.head()
# Out:
#        Country  Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan              60.0           AF                58.10%
# 1      Albania             105.0           AL                43.10%
# 2      Algeria              18.0           DZ                17.40%
# 3      Andorra             164.0           AD                40.00%
# 4       Angola              26.0           AO                47.50%
#
#   Land Area(Km2) Armed Forces size           Birth Rate  Calling Code  \
# 0         652.23               323                32.49          93.0
# 1         28.748                 9                11.78         355.0
# 2      2,381,741               317                24.28         213.0
# 3            468               NaN  2023-02-07 00:00:00         376.0
# 4      1,246,700               117                40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# ...

# %% [markdown]
# bad data?

# %% [markdown]
# ### I have no sheets for practising `sheet_name='name'`
