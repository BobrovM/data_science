# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 2*np.pi)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].plot(x, np.sin(x))
axes[1].plot(x, np.cos(x))
plt.show()

# %%
data = pd.read_csv('Tesla.csv', parse_dates=True, index_col='Date')

# %%
data.head()
# Out:
#              High        Low       Open      Close    Volume  Adj Close
# Date
# 2010-06-29  25.00  17.540001  19.000000  23.889999  18766300  23.889999
# 2010-06-30  30.42  23.299999  25.790001  23.830000  17187100  23.830000
# 2010-07-01  25.92  20.270000  25.000000  21.959999   8218800  21.959999
# 2010-07-02  23.10  18.709999  23.000000  19.200001   5139800  19.200001
# 2010-07-06  20.00  15.830000  20.000000  16.110001   6866900  16.110001

# %%
from pandas.tseries.offsets import MonthEnd

def get_monthly_dates(data):
    date = data.index[0]
    dates = []
    while date < data.index[-1]:
        date = date + MonthEnd(1)
        dates.append(date)
    return dates

# %%
import math

# %%
year = 2010

fig, axes = plt.subplots(2, 2, figsize=(20,20), sharey='row')

for row in range(2):
    for column in range(2):
        year_data = data[data.index.year == year]
        dates = get_monthly_dates(year_data)
        axes[row, column].plot(year_data['High'], label='High', color='g')
        axes[row, column].plot(year_data['Low'], label='Low', color='r')
        axes[row, column].set_title('Stock prices in {}, USD'.format(year))
        #axes[row, column].set_xlabel('Dates')
        #axes[row, column].set_ylabel('Stock prices, USD')
        axes[row, column].set_xticks(dates)
        axes[row, column].set_xticklabels([pd.to_datetime(str(date)).strftime("%m.%d.%Y")\
                                          for date in dates], rotation=45)
        yticks = range(math.floor(min(year_data['Low'])), math.ceil(max(year_data['High'])), 5)
        axes[row, column].set_yticks(yticks)
        axes[row, column].set_yticklabels(yticks)
        
        axes[row, column].grid()
        axes[row, column].legend(loc='upper left', title='Stock prices')
        
        year += 1
      
first_profit_report_date = pd.Timestamp(day=8, month=5, year=2013)
second_afterprofit_report_date = pd.Timestamp(day=7, month=8, year=2013)

plt.setp(axes[0:], yticks=range(14, 40, 2), yticklabels=range(14, 40, 2))
plt.setp(axes[1:], yticks=range(15, 200, 10), yticklabels=range(15, 200, 10))
plt.setp(axes, xlabel='Dates', ylabel='Stock prices, USD')

axes[1, 1].axvline(first_profit_report_date, ls='--', color='b', label=first_profit_report_date.strftime('%m-%d-%Y'))
axes[1, 1].axvspan(first_profit_report_date, second_afterprofit_report_date, facecolor='g', alpha=0.5, label='Area between 1st and 2nd reports in 2013')
plt.legend(loc='upper left', title='Stock prices')

plt.show()

# %% [markdown]
# ### Self practise

# %%
data_os = pd.read_csv('ap-northeast-1.csv')
data_os.head()
# Out:
#    2017-05-08 21:46:36+00:00  c3.8xlarge     Windows  ap-northeast-1a  1.6503
# 0  2017-05-08 21:46:36+00:00  c3.8xlarge     Windows  ap-northeast-1c  1.7461
# 1  2017-05-08 21:46:34+00:00    i3.large  SUSE Linux  ap-northeast-1c  0.1223
# 2  2017-05-08 21:46:34+00:00    i3.large  Linux/UNIX  ap-northeast-1c  0.0223
# 3  2017-05-08 21:46:17+00:00  c4.8xlarge  SUSE Linux  ap-northeast-1a  0.7890
# 4  2017-05-08 21:46:17+00:00  c4.8xlarge  Linux/UNIX  ap-northeast-1a  0.6890

# %%
data_os.columns = ['datetime', 'architecture', 'os', 'idk', 'version_qm']
#I have no idea what some of this data is. 
#I was just given it with a task and thats all...
data_os.head()
# Out:
#                     datetime architecture          os              idk  \
# 0  2017-05-08 21:46:36+00:00   c3.8xlarge     Windows  ap-northeast-1c
# 1  2017-05-08 21:46:34+00:00     i3.large  SUSE Linux  ap-northeast-1c
# 2  2017-05-08 21:46:34+00:00     i3.large  Linux/UNIX  ap-northeast-1c
# 3  2017-05-08 21:46:17+00:00   c4.8xlarge  SUSE Linux  ap-northeast-1a
# 4  2017-05-08 21:46:17+00:00   c4.8xlarge  Linux/UNIX  ap-northeast-1a
#
#    version_qm
# 0      1.7461
# 1      0.1223
# 2      0.0223
# 3      0.7890
# 4      0.6890

# %%
data_win = data_os[data_os['os'] == 'Windows']
data_win.head()
# Out:
#                      datetime architecture       os              idk  \
# 0   2017-05-08 21:46:36+00:00   c3.8xlarge  Windows  ap-northeast-1c
# 15  2017-05-08 21:46:03+00:00   c4.8xlarge  Windows  ap-northeast-1a
# 22  2017-05-08 21:45:53+00:00    c4.xlarge  Windows  ap-northeast-1c
# 25  2017-05-08 21:45:16+00:00   r3.8xlarge  Windows  ap-northeast-1c
# 32  2017-05-08 21:45:02+00:00     m3.large  Windows  ap-northeast-1c
#
#     version_qm
# 0       1.7461
# 15      1.6561
# 22      0.2139
# 25      1.0246
# 32      0.1462

# %%
data_i = data_os[data_os['architecture'].astype(str).str[0] == 'i']
data_i.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103780 entries, 1 to 1956704
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datetime      103780 non-null  object
#  1   architecture  103780 non-null  object
#  2   os            103780 non-null  object
#  3   idk           103780 non-null  object
#  4   version_qm    103780 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 4.8+ MB

# %% [markdown]
# this is very funny... there are no prices column. How am i supposed to build 2 graphs with date-price by os and arvchitecture????? Damn it
